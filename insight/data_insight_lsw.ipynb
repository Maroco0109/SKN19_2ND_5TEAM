# %% [markdown]
# # 이승원

# %% [markdown]
# ### 초기 설정(지완님꺼 가져옴)

# %%
# 데이터 분석 및 시각화에 필요한 라이브러리들을 가져옵니다.
# pathlib: 파일 경로를 쉽게 다루기 위한 라이브러리
from pathlib import Path
# display: Jupyter Notebook에서 데이터프레임 등을 예쁘게 출력하기 위해 사용
from IPython.display import display
import matplotlib.pyplot as plt
import matplotlib.ticker as mstick
import pandas as pd
import seaborn as sns

# seaborn의 기본 테마를 설정합니다. 'whitegrid' 스타일과 'crest' 색상 팔레트를 사용합니다.
sns.set_theme(style="whitegrid", palette="crest")

# 시각화에서 한글이 깨지지 않도록 나눔고딕 폰트를 설정합니다.
# 시스템에 폰트가 설치되어 있지 않으면 오류가 발생할 수 있어 try-except 구문으로 감쌌습니다.
try:
    plt.rc('font', family='NanumGothic')
except Exception:
    pass
# 마이너스 부호가 깨지는 것을 방지하는 설정입니다.
plt.rc('axes', unicode_minus=False)


# 데이터셋 병합
DATA_PATH1 = Path('../data/2022Data_part1.csv')
DATA_PATH2 = Path('../data/2022Data_part2.csv')
df_part1 = pd.read_csv(DATA_PATH1)
df_part2 = pd.read_csv(DATA_PATH2)

# DeepSurv 분석용 샘플 데이터를 불러오고 기본 전처리를 수행합니다.
df = pd.concat([df_part1, df_part2], ignore_index=True).rename(columns=lambda col: col.strip())
# Out:
# C:\Users\vhqhr\AppData\Local\Temp\ipykernel_12924\657887825.py:27: DtypeWarning: Columns (24) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_part1 = pd.read_csv(DATA_PATH1)

# %% [markdown]
# ### 기본 데이터 분석

# %%
df
# Out:
#         Patient ID Age recode with <1 year olds and 90+     Sex  \
# 0              671                          65-69 years    Male
# 1              812                          65-69 years  Female
# 2              878                          60-64 years    Male
# 3             1018                          70-74 years  Female
# 4             1269                          40-44 years  Female
# ...            ...                                  ...     ...
# 528398    63452555                          75-79 years  Female
# 528399    63452558                          70-74 years    Male
# 528400    63452564                          75-79 years    Male
# 528401    63452565                            90+ years  Female
# 528402    63452570                          80-84 years    Male
#
#         Year of diagnosis  Year of follow-up recode  \
# 0                    2018                      2022
# 1                    2022                      2022
# 2                    2004                      2022
# 3                    2011                      2022
# 4                    2007                      2022
# ...                   ...                       ...
# 528398               2022                      2022
# 528399               2022                      2022
# 528400               2022                      2022
# 528401               2022                      2022
# 528402               2020                      2022
#
#        Race recode (W, B, AI, API) Site recode ICD-O-3/WHO 2008  Primary Site  \
# 0                            White            Lung and Bronchus           341
# 1                            White                      Stomach           163
# 2                            White                     Appendix           181
# 3                            White              Ascending Colon           182
# 4                            White                Sigmoid Colon           187
# ...                            ...                          ...           ...
# 528398                       White            Lung and Bronchus           349
# 528399                       Black            Lung and Bronchus           349
# 528400                       White         Large Intestine, NOS           189
# 528401                       White         Large Intestine, NOS           189
# 528402                       White            Lung and Bronchus           349
#
#         Primary Site - labeled Derived Summary Grade 2018 (2018+)  ...  \
# 0       C34.1-Upper lobe, lung                                  3  ...
# 1         C16.3-Gastric antrum                                  L  ...
# 2               C18.1-Appendix                           Blank(s)  ...
# 3        C18.2-Ascending colon                           Blank(s)  ...
# 4          C18.7-Sigmoid colon                           Blank(s)  ...
# ...                        ...                                ...  ...
# 528398         C34.9-Lung, NOS                                  9  ...
# 528399         C34.9-Lung, NOS                                  9  ...
# 528400        C18.9-Colon, NOS                                  9  ...
# 528401        C18.9-Colon, NOS                                  9  ...
# 528402         C34.9-Lung, NOS                                  9  ...
#
#             COD to site recode             Sequence number  \
# 0                        Alive  2nd of 2 or more primaries
# 1                        Alive            One primary only
# 2                        Alive  2nd of 2 or more primaries
# 3                        Alive  3rd of 3 or more primaries
# 4                        Alive            One primary only
# ...                        ...                         ...
# 528398       Lung and Bronchus            One primary only
# 528399       Lung and Bronchus            One primary only
# 528400  Colon excluding Rectum            One primary only
# 528401  Colon excluding Rectum            One primary only
# 528402       Lung and Bronchus            One primary only
#
#        Median household income inflation adj to 2023  \
# 0                                          $120,000+
# 1                                          $120,000+
# 2                                $100,000 - $109,999
# 3                                $110,000 - $119,999
# 4                                $110,000 - $119,999
# ...                                              ...
# 528398                             $55,000 - $59,999
# 528399                             $50,000 - $54,999
# 528400                             $80,000 - $84,999
# 528401                             $90,000 - $94,999
# 528402                             $45,000 - $49,999
#
#         Number of Cores Positive Recode (2010+)  \
# 0                                      Blank(s)
# 1                                      Blank(s)
# 2                                      Blank(s)
# 3                                      Blank(s)
# 4                                      Blank(s)
# ...                                         ...
# 528398                                 Blank(s)
# 528399                                 Blank(s)
# 528400                                 Blank(s)
# 528401                                 Blank(s)
# 528402                                 Blank(s)
#
#        Number of Cores Examined Recode (2010+)  \
# 0                                     Blank(s)
# 1                                     Blank(s)
# 2                                     Blank(s)
# 3                                     Blank(s)
# 4                                     Blank(s)
# ...                                        ...
# 528398                                Blank(s)
# 528399                                Blank(s)
# 528400                                Blank(s)
# 528401                                Blank(s)
# 528402                                Blank(s)
#
#        EOD Primary Tumor Recode (2018+) PRCDA 2020  \
# 0                                   450  Not PRCDA
# 1                                   100  Not PRCDA
# 2                              Blank(s)  Not PRCDA
# 3                              Blank(s)  Not PRCDA
# 4                              Blank(s)  Not PRCDA
# ...                                 ...        ...
# 528398                              999  Not PRCDA
# 528399                              999  Not PRCDA
# 528400                              999  Not PRCDA
# 528401                              999  Not PRCDA
# 528402                              999  Not PRCDA
#
#                                      Survival months flag Survival months  \
# 0       Complete dates are available and there are mor...            0059
# 1       Complete dates are available and there are mor...            0007
# 2       Complete dates are available and there are mor...            0218
# 3       Complete dates are available and there are mor...            0134
# 4       Complete dates are available and there are mor...            0187
# ...                                                   ...             ...
# 528398  Complete dates are available and there are mor...            0002
# 528399  Complete dates are available and there are mor...            0002
# 528400  Complete dates are available and there are mor...            0002
# 528401  Complete dates are available and there are mor...            0000
# 528402  Complete dates are available and there are mor...            0023
#
#        Vital status recode (study cutoff used)
# 0                                        Alive
# 1                                        Alive
# 2                                        Alive
# 3                                        Alive
# 4                                        Alive
# ...                                        ...
# 528398                                    Dead
# 528399                                    Dead
# 528400                                    Dead
# 528401                                    Dead
# 528402                                    Dead
#
# [528403 rows x 26 columns]

# %%
df.info()
# 0   Patient ID                           528403 non-null  int64 
# 3   Year of diagnosis                    528403 non-null  int64 
# 4   Year of follow-up recode             528403 non-null  int64 
# 7   Primary Site                         528403 non-null  int64 
# 13  RX Summ--Surg Prim Site (1998+)      528403 non-null  int64 
# 빼고 다 object형
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 528403 entries, 0 to 528402
# Data columns (total 26 columns):
#  #   Column                                                       Non-Null Count   Dtype
# ---  ------                                                       --------------   -----
#  0   Patient ID                                                   528403 non-null  int64
#  1   Age recode with <1 year olds and 90+                         528403 non-null  object
#  2   Sex                                                          528403 non-null  object
#  3   Year of diagnosis                                            528403 non-null  int64
#  4   Year of follow-up recode                                     528403 non-null  int64
#  5   Race recode (W, B, AI, API)                                  528403 non-null  object
#  6   Site recode ICD-O-3/WHO 2008                                 528403 non-null  object
#  7   Primary Site                                                 528403 non-null  int64
#  8   Primary Site - labeled                                       528403 non-null  object
#  9   Derived Summary Grade 2018 (2018+)                           528403 non-null  object
#  10  Laterality                                                   528403 non-null  object
#  11  EOD Schema ID Recode (2010+)                                 528403 non-null  object
#  12  Combined Summary Stage with Expanded Regional Codes (2004+)  528403 non-null  object
#  13  RX Summ--Surg Prim Site (1998+)                              528403 non-null  int64
#  14  RX Summ--Scope Reg LN Sur (2003+)                            338441 non-null  object
#  15  RX Summ--Surg Oth Reg/Dis (2003+)                            528403 non-null  object
#  16  COD to site recode                                           528403 non-null  object
#  17  Sequence number                                              528403 non-null  object
#  18  Median household income inflation adj to 2023                528403 non-null  object
#  19  Number of Cores Positive Recode (2010+)                      528403 non-null  object
#  20  Number of Cores Examined Recode (2010+)                      528403 non-null  object
#  21  EOD Primary Tumor Recode (2018+)                             528403 non-null  object
#  22  PRCDA 2020                                                   528403 non-null  object
#  23  Survival months flag                                         528403 non-null  object
#  24  Survival months                                              528403 non-null  object
#  25  Vital status recode (study cutoff used)                      528403 non-null  object
# dtypes: int64(5), object(21)
# memory usage: 104.8+ MB

# %%
df.describe()
# Out:
#          Patient ID  Year of diagnosis  Year of follow-up recode  \
# count  5.284030e+05      528403.000000                  528403.0
# mean   3.360487e+07        2016.103166                    2022.0
# std    1.834805e+07           5.813579                       0.0
# min    6.710000e+02        2000.000000                    2022.0
# 25%    1.698095e+07        2013.000000                    2022.0
# 50%    3.548133e+07        2018.000000                    2022.0
# 75%    5.007004e+07        2021.000000                    2022.0
# max    6.345257e+07        2022.000000                    2022.0
#
#         Primary Site  RX Summ--Surg Prim Site (1998+)
# count  528403.000000                    528403.000000
# mean      247.653509                        24.272519
# std        77.731198                        18.876716
# min       160.000000                         0.000000
# 25%       182.000000                         0.000000
# 50%       187.000000                        30.000000
# 75%       341.000000                        40.000000
# max       349.000000                        99.000000

# %%
df.columns
# Out:
# Index(['Patient ID', 'Age recode with <1 year olds and 90+', 'Sex',
#        'Year of diagnosis', 'Year of follow-up recode',
#        'Race recode (W, B, AI, API)', 'Site recode ICD-O-3/WHO 2008',
#        'Primary Site', 'Primary Site - labeled',
#        'Derived Summary Grade 2018 (2018+)', 'Laterality',
#        'EOD Schema ID Recode (2010+)',
#        'Combined Summary Stage with Expanded Regional Codes (2004+)',
#        'RX Summ--Surg Prim Site (1998+)', 'RX Summ--Scope Reg LN Sur (2003+)',
#        'RX Summ--Surg Oth Reg/Dis (2003+)', 'COD to site recode',
#        'Sequence number', 'Median household income inflation adj to 2023',
#        'Number of Cores Positive Recode (2010+)',
#        'Number of Cores Examined Recode (2010+)',
#        'EOD Primary Tumor Recode (2018+)', 'PRCDA 2020',
#        'Survival months flag', 'Survival months',
#        'Vital status recode (study cutoff used)'],
#       dtype='object')

# %%
# 지완님이 만든 칼럼 설명 이용
column_df = pd.read_csv('../data/seer_columns_ko_mapping.csv')

# %%
# df['Survival months'] = pd.to_numeric(df['Survival months'], errors='coerce')

# %%
columns_name = df.columns
for column in columns_name:
    print(f"<{column} : {column_df.loc[column_df['original_name']==column, 'korean_name'].iloc[0]}>의 유니크한 내용\n{df[column].unique()}")
    print('그 개수',df[column].nunique(), end='\n\n')
# Out:
# <Patient ID : 환자 ID>의 유니크한 내용
# [     671      812      878 ... 63452564 63452565 63452570]
# 그 개수 501633
#
# <Age recode with <1 year olds and 90+ : 나이 재코딩(만 1세 미만·90세 이상 구간 포함)>의 유니크한 내용
# ['65-69 years' '60-64 years' '70-74 years' '40-44 years' '45-49 years'
#  '85-89 years' '55-59 years' '75-79 years' '30-34 years' '80-84 years'
#  '50-54 years' '90+ years' '35-39 years' '20-24 years' '01-04 years'
#  '10-14 years' '15-19 years' '25-29 years' '00 years' '05-09 years']
# 그 개수 20
#
# <Sex : 성별>의 유니크한 내용
# ['Male' 'Female']
# 그 개수 2
#
# <Year of diagnosis : 진단연도>의 유니크한 내용
# [2018 2022 2004 2011 2007 2020 2019 2021 2016 2010 2015 2003 2012 2005
#  2013 2017 2002 2009 2006 2014 2000 2001 2008]
# 그 개수 23
#
# <Year of follow-up recode : 추적연도(재코딩)>의 유니크한 내용
# [2022]
# 그 개수 1
#
# <Race recode (W, B, AI, API) : 인종 재코딩(백/흑/아메리카원주민/아시아·태평양)>의 유니크한 내용
# ['White' 'Asian or Pacific Islander' 'Black'
#  'American Indian/Alaska Native' 'Unknown']
# 그 개수 5
#
# <Site recode ICD-O-3/WHO 2008 : 부위 재코딩(ICD-O-3/WHO 2008)>의 유니크한 내용
# ['Lung and Bronchus' 'Stomach' 'Appendix' 'Ascending Colon'
#  'Sigmoid Colon' 'Intrahepatic Bile Duct' 'Transverse Colon'
#  'Splenic Flexure' 'Descending Colon' 'Liver' 'Cecum'
#  'Large Intestine, NOS' 'Hepatic Flexure' 'NHL - Extranodal' 'Myeloma'
#  'Hodgkin - Extranodal' 'Kaposi Sarcoma' 'Miscellaneous'
#  'Other Myeloid/Monocytic Leukemia' 'Mesothelioma']
# 그 개수 20
#
# <Primary Site : 원발부위(코드)>의 유니크한 내용
# [341 163 181 182 187 221 343 184 185 186 349 220 180 342 189 165 169 340
#  160 168 161 188 162 166 183 348 164]
# 그 개수 27
#
# <Primary Site - labeled : 원발부위(라벨)>의 유니크한 내용
# ['C34.1-Upper lobe, lung' 'C16.3-Gastric antrum' 'C18.1-Appendix'
#  'C18.2-Ascending colon' 'C18.7-Sigmoid colon'
#  'C22.1-Intrahepatic bile duct' 'C34.3-Lower lobe, lung'
#  'C18.4-Transverse colon' 'C18.5-Splenic flexure of colon'
#  'C18.6-Descending colon' 'C34.9-Lung, NOS' 'C22.0-Liver' 'C18.0-Cecum'
#  'C34.2-Middle lobe, lung' 'C18.9-Colon, NOS'
#  'C16.5-Lesser curvature of stomach NOS' 'C16.9-Stomach, NOS'
#  'C34.0-Main bronchus' 'C16.0-Cardia, NOS'
#  'C16.8-Overlapping lesion of stomach' 'C16.1-Fundus of stomach'
#  'C18.8-Overlapping lesion of colon' 'C16.2-Body of stomach'
#  'C16.6-Greater curvature of stomach NOS' 'C18.3-Hepatic flexure of colon'
#  'C34.8-Overlapping lesion of lung' 'C16.4-Pylorus']
# 그 개수 27
#
# <Derived Summary Grade 2018 (2018+) : 파생 요약 등급 2018>의 유니크한 내용
# ['3' 'L' 'Blank(s)' '9' '2' '1' '4' '8' 'A' 'H' 'C' 'D' 'B']
# 그 개수 13
#
# <Laterality : 좌우측성>의 유니크한 내용
# ['Right - origin of primary' 'Not a paired  site'
#  'Left - origin of primary'
#  'Paired site, but no information concerning laterality'
#  'Bilateral, single primary' 'Only one side - side unspecified']
# 그 개수 6
#
# <EOD Schema ID Recode (2010+) : EOD 스키마 ID(재코딩)>의 유니크한 내용
# ['Lung' 'GIST' 'Blank(s)' 'Colon and Rectum' 'Bile Ducts Intrahepat'
#  'Liver' 'Stomach (including all C16.0)' 'Appendix' 'Lymphoma'
#  'NET Appendix' 'NET Stomach' 'Lymphoma-CLL/SLL' 'NET Colon and Rectum'
#  'Soft Tissues Abdomen and Thoracic (excluding Heart, Mediastinum, Pleura)'
#  'Kaposi Sarcoma' 'Plasma Cell Disorders' 'Soft Tissue Other' 'HemeRetic'
#  'Pleural Mesothelioma']
# 그 개수 19
#
# <Combined Summary Stage with Expanded Regional Codes (2004+) : 결합 요약 병기(확장 지역 코드 포함)>의 유니크한 내용
# ['Regional by both direct extension and lymph node involvement'
#  'Localized only' 'Regional lymph nodes involved only'
#  'Distant site(s)/node(s) involved' 'Regional by direct extension only'
#  'Blank(s)' 'Unknown/unstaged/unspecified/DCO' 'In situ']
# 그 개수 8
#
# <RX Summ--Surg Prim Site (1998+) : 치료 요약—원발부위 수술>의 유니크한 내용
# [33 30 40  0 26 80 21 23 45 51 28 70 22 55 41 42 61 16 99 27 32 60 50 12
#  25 56 52 20 29 36 66 24 37 62 90 10 31 46 65 19 47 48 15 13 75 38 63 17
#  14 59 98 11]
# 그 개수 52
#
# <RX Summ--Scope Reg LN Sur (2003+) : 치료 요약—국소 림프절 수술 범위>의 유니크한 내용
# ['4 or more regional lymph nodes removed' nan
#  'Biopsy or aspiration of regional lymph node, NOS'
#  'Unknown or not applicable' 'Blank(s)'
#  'Number of regional lymph nodes removed unknown'
#  '1 to 3 regional lymph nodes removed' 'Sentinel lymph node biopsy'
#  'Sentinel node biopsy and lym nd removed same/unstated time'
#  'Sentinel node biopsy and lym nd removed different times']
# 그 개수 9
#
# <RX Summ--Surg Oth Reg/Dis (2003+) : 치료 요약—기타 국소/원격 질환 수술>의 유니크한 내용
# ['None; diagnosed at autopsy' 'Blank(s)' 'Unknown; death certificate only'
#  'Non-primary surgical procedure to distant site'
#  'Non-primary surgical procedure to other regional sites'
#  'Any combo of sur proc to oth rg, dis lym nd, and/or dis site'
#  'Non-primary surgical procedure performed'
#  'Non-primary surgical procedure to distant lymph node(s)']
# 그 개수 8
#
# <COD to site recode : 사망원인→부위 재코딩>의 유니크한 내용
# ['Alive' 'Intrahepatic Bile Duct' 'Lung and Bronchus'
#  'Miscellaneous Malignant Cancer' 'Other Cause of Death'
#  'Colon excluding Rectum' 'Diseases of Heart'
#  'Alzheimers (ICD-9 and 10 only)' 'Stomach'
#  'Nephritis, Nephrotic Syndrome and Nephrosis' 'Cerebrovascular Diseases'
#  'Liver' 'Breast' 'Chronic Obstructive Pulmonary Disease and Allied Cond'
#  'Chronic Lymphocytic Leukemia' 'Chronic Liver Disease and Cirrhosis'
#  'Salivary Gland' 'Other Infectious and Parasitic Diseases including HIV'
#  'Prostate' 'Non-Hodgkin Lymphoma' 'Diabetes Mellitus'
#  'State DC not available or state DC available but no COD'
#  'Kidney and Renal Pelvis' 'Hypertension without Heart Disease' 'Myeloma'
#  'Acute Myeloid Leukemia' 'Brain and Other Nervous System'
#  'Pneumonia and Influenza' 'Pancreas' 'Stomach and Duodenal Ulcers'
#  'Small Intestine' 'Accidents and Adverse Effects' 'Corpus Uteri'
#  'Urinary Bladder' 'In situ, benign or unknown behavior neoplasm'
#  'Atherosclerosis' 'Esophagus' 'Cervix Uteri'
#  'Suicide and Self-Inflicted Injury' 'Anus, Anal Canal and Anorectum'
#  'Melanoma of the Skin' 'Rectum and Rectosigmoid Junction' 'Uterus, NOS'
#  'Soft Tissue including Heart' 'Non-Melanoma Skin' 'Tongue' 'Septicemia'
#  'Thyroid' 'Floor of Mouth' 'Aleukemic, Subleukemic and NOS'
#  'Other Diseases of Arteries, Arterioles, Capillaries'
#  'Aortic Aneurysm and Dissection' 'Pleura' 'Ovary' 'Other Biliary'
#  'Congenital Anomalies' 'Hypopharynx' 'Other Lymphocytic Leukemia'
#  'Nasopharynx' 'Penis' 'Other Digestive Organs' 'Bones and Joints'
#  'Tonsil' 'Peritoneum, Omentum and Mesentery' 'Larynx' 'Hodgkin Lymphoma'
#  'Retroperitoneum' 'Other Myeloid/Monocytic Leukemia' 'Tuberculosis'
#  'Symptoms, Signs and Ill-Defined Conditions' 'Oropharynx' 'Vagina'
#  'Gallbladder' 'Gum and Other Mouth' 'Other Endocrine including Thymus'
#  'Homicide and Legal Intervention'
#  'Trachea, Mediastinum and Other Respiratory Organs' 'Testis'
#  'Acute Lymphocytic Leukemia' 'Other Urinary Organs'
#  'Other Oral Cavity and Pharynx' 'Other Female Genital Organs'
#  'Nose, Nasal Cavity and Middle Ear' 'Other Acute Leukemia' 'Ureter'
#  'Vulva' 'Chronic Myeloid Leukemia' 'Eye and Orbit' 'Lip'
#  'Complications of Pregnancy, Childbirth, Puerperium']
# 그 개수 90
#
# <Sequence number : 종양 순번>의 유니크한 내용
# ['2nd of 2 or more primaries' 'One primary only'
#  '3rd of 3 or more primaries' '1st of 2 or more primaries'
#  '5th of 5 or more primaries' '6th of 6 or more primaries'
#  '4th of 4 or more primaries' '7th of 7 or more primaries'
#  '8th of 8 or more primaries' '13th of 13 or more primaries'
#  '9th of 9 or more primaries' '11th of 11 or more primaries'
#  '14th of 14 or more primaries' '34th of 34 or more primaries'
#  '30th of 30 or more primaries' '12th of 12 or more primaries'
#  '20th of 20 or more primaries' '10th of 10 or more primaries']
# 그 개수 18
#
# <Median household income inflation adj to 2023 : 가구 중위소득(2023년 물가보정)>의 유니크한 내용
# ['$120,000+' '$100,000 - $109,999' '$110,000 - $119,999'
#  '$90,000 - $94,999' '$95,000 - $99,999' '$75,000 - $79,999'
#  '$85,000 - $89,999' '$80,000 - $84,999' '$70,000 - $74,999'
#  '$65,000 - $69,999' 'Unknown/missing/no match/Not 1990-2023'
#  '$60,000 - $64,999' '$55,000 - $59,999' '$50,000 - $54,999'
#  '$45,000 - $49,999' '$40,000 - $44,999' '< $40,000']
# 그 개수 17
#
# <Number of Cores Positive Recode (2010+) : (전립선) 생검 양성 코어 수(재코딩)>의 유니크한 내용
# ['Blank(s)']
# 그 개수 1
#
# <Number of Cores Examined Recode (2010+) : (전립선) 생검 검사 코어 수(재코딩)>의 유니크한 내용
# ['Blank(s)']
# 그 개수 1
#
# <EOD Primary Tumor Recode (2018+) : EOD 원발종양(재코딩)>의 유니크한 내용
# ['450' '100' 'Blank(s)' '999' '300' '400' '700' '200' '050' '600' '650'
#  '500' '800' '350' '250' '675' '750' '150' '980' '070' '550' '000' '575']
# 그 개수 23
#
# <PRCDA 2020 : PRCDA 2020>의 유니크한 내용
# ['Not PRCDA' 'PRCDA' 'Unknown PRCDA']
# 그 개수 3
#
# <Survival months flag : 생존개월 플래그>의 유니크한 내용
# ['Complete dates are available and there are more than 0 days of survival'
#  'Incomplete dates are available and there cannot be zero days of follow-up'
#  'Not calculated because a Death Certificate Only or Autopsy Only case'
#  'Complete dates are available and there are 0 days of survival'
#  'Incomplete dates are available and there could be zero days of follow-up']
# 그 개수 5
#
# <Survival months : 생존개월>의 유니크한 내용
# [ 59.   7. 218. 134. 187.  22.  46.  27.  16.  73. 154.  79. 235.  20.
#    3. 237.  11.   2. 130. 215.  49.  17. 111.  33. 131.  90.  35.  62.
#  180. 113. 244. 246. 241.  76. 157. 125. 196.   9.  98. 121. 228.  50.
#  162.  40. 185.  32.  15.  94.  72. 103.  38.  78.   5.  37. 105. 209.
#  192.  19. 227. 128.  75.  10. 271.  70.  58. 195.   4. 267.  69.  82.
#  251. 201.  86. 112. 124. 129.  52. 212.  31. 160.  51.  92.  13. 152.
#  101. 222. 221. 247.  87. 159. 164. 266. 219. 274.  45. 202. 250. 231.
#   nan   8.  24.  84. 179.  66. 236. 148. 233.   6. 265. 126. 139.  18.
#  116. 206.  43. 119. 170.  63.  44.  21. 242. 158. 123. 144.  34.   1.
#   54.  68. 120. 102.  26. 216. 165. 133. 272.  28. 167. 273. 190. 213.
#   85.  71.  99. 269. 115.  93. 114. 118.  23.  88. 243.  64. 153.  36.
#   30. 181.  81. 248.  41. 183. 220.  74. 253. 142. 239. 224.  42. 270.
#  189. 198.  56.  53. 163.  91.  29.  67.  61.  77. 173.  47. 132. 238.
#   65. 117. 254. 141.  14. 249. 257.  83. 140. 122. 171. 137. 100. 146.
#   60. 108. 182. 225. 156.  57.  89.   0. 177.  96. 234. 208.  39.  80.
#  169. 172. 174. 107. 211. 207.  48. 106.  25. 204. 186. 184. 136. 155.
#  230. 197. 268. 166. 263.  95. 178. 214. 104. 176.  12. 229. 143. 252.
#  151. 194. 168. 210. 193. 191. 264. 127. 109. 135.  55. 260. 110. 256.
#  147. 138. 175. 205. 188. 161. 259. 275.  97. 261. 245. 149. 258. 262.
#  232. 255. 240. 199. 150. 145. 226. 200. 203. 223. 217.]
# 그 개수 276
#
# <Vital status recode (study cutoff used) : 생존상태 재코딩(연구 절단점 기준)>의 유니크한 내용
# ['Alive' 'Dead']
# 그 개수 2

# %%
patient_value_counts = df['Patient ID'].value_counts()
dupe_id = patient_value_counts[patient_value_counts > 1]          # 중복 ID와 각 등장 횟수
print('중복 환자 수:', dupe_id.shape[0])

print(dupe_id.head(5))       # 상위 5개
# Out:
# 중복 환자 수: 24430
# Patient ID
# 24206472    7
# 16011977    6
# 10709680    6
# 34959205    6
# 16257106    6
# Name: count, dtype: int64

# %%
df[df["Patient ID"] == 24206472]  # 최대 중복 행을 가지는 사람.
# Out:
#         Patient ID Age recode with <1 year olds and 90+     Sex  \
# 167297    24206472                          50-54 years  Female
# 167298    24206472                          45-49 years  Female
# 167299    24206472                          40-44 years  Female
# 167300    24206472                          40-44 years  Female
# 167301    24206472                          50-54 years  Female
# 167302    24206472                          50-54 years  Female
# 167303    24206472                          55-59 years  Female
#
#         Year of diagnosis  Year of follow-up recode  \
# 167297               2014                      2022
# 167298               2011                      2022
# 167299               2005                      2022
# 167300               2007                      2022
# 167301               2016                      2022
# 167302               2015                      2022
# 167303               2022                      2022
#
#        Race recode (W, B, AI, API) Site recode ICD-O-3/WHO 2008  Primary Site  \
# 167297                       White                      Stomach           162
# 167298                       White                      Stomach           162
# 167299                       White                      Stomach           169
# 167300                       White                      Stomach           162
# 167301                       White                      Stomach           169
# 167302                       White                      Stomach           162
# 167303                       White                      Stomach           166
#
#                         Primary Site - labeled  \
# 167297                   C16.2-Body of stomach
# 167298                   C16.2-Body of stomach
# 167299                      C16.9-Stomach, NOS
# 167300                   C16.2-Body of stomach
# 167301                      C16.9-Stomach, NOS
# 167302                   C16.2-Body of stomach
# 167303  C16.6-Greater curvature of stomach NOS
#
#        Derived Summary Grade 2018 (2018+)  ... COD to site recode  \
# 167297                           Blank(s)  ...              Alive
# 167298                           Blank(s)  ...              Alive
# 167299                           Blank(s)  ...              Alive
# 167300                           Blank(s)  ...              Alive
# 167301                           Blank(s)  ...              Alive
# 167302                           Blank(s)  ...              Alive
# 167303                                  9  ...              Alive
#
#                    Sequence number  \
# 167297  4th of 4 or more primaries
# 167298  3rd of 3 or more primaries
# 167299  1st of 2 or more primaries
# 167300  2nd of 2 or more primaries
# 167301  6th of 6 or more primaries
# 167302  5th of 5 or more primaries
# 167303  7th of 7 or more primaries
#
#        Median household income inflation adj to 2023  \
# 167297                                     $120,000+
# 167298                           $110,000 - $119,999
# 167299                                     $120,000+
# 167300                                     $120,000+
# 167301                                     $120,000+
# 167302                                     $120,000+
# 167303                                     $120,000+
#
#         Number of Cores Positive Recode (2010+)  \
# 167297                                 Blank(s)
# 167298                                 Blank(s)
# 167299                                 Blank(s)
# 167300                                 Blank(s)
# 167301                                 Blank(s)
# 167302                                 Blank(s)
# 167303                                 Blank(s)
#
#        Number of Cores Examined Recode (2010+)  \
# 167297                                Blank(s)
# 167298                                Blank(s)
# 167299                                Blank(s)
# 167300                                Blank(s)
# 167301                                Blank(s)
# 167302                                Blank(s)
# 167303                                Blank(s)
#
#        EOD Primary Tumor Recode (2018+) PRCDA 2020  \
# 167297                         Blank(s)  Not PRCDA
# 167298                         Blank(s)  Not PRCDA
# 167299                         Blank(s)  Not PRCDA
# 167300                         Blank(s)  Not PRCDA
# 167301                         Blank(s)  Not PRCDA
# 167302                         Blank(s)  Not PRCDA
# 167303                              999  Not PRCDA
#
#                                      Survival months flag Survival months  \
# 167297  Complete dates are available and there are mor...            0098
# 167298  Complete dates are available and there are mor...            0139
# 167299  Complete dates are available and there are mor...            0208
# 167300  Complete dates are available and there are mor...            0181
# 167301  Complete dates are available and there are mor...            0072
# 167302  Complete dates are available and there are mor...            0085
# 167303  Complete dates are available and there are mor...            0011
#
#        Vital status recode (study cutoff used)
# 167297                                   Alive
# 167298                                   Alive
# 167299                                   Alive
# 167300                                   Alive
# 167301                                   Alive
# 167302                                   Alive
# 167303                                   Alive
#
# [7 rows x 26 columns]

# %%
df[df["Patient ID"] == 16011977]
# Out:
# 104259    Regional by direct extension only
# 104260    Regional by direct extension only
# 104261                             Blank(s)
# 104262                       Localized only
# 104263                       Localized only
# 104264                       Localized only
# Name: Combined Summary Stage with Expanded Regional Codes (2004+), dtype: object

# %%
df[df['Sequence number'] == '34th of 34 or more primaries']
# Out:
#         Patient ID Age recode with <1 year olds and 90+     Sex  \
# 219895    27987549                          45-49 years  Female
#
#         Year of diagnosis  Year of follow-up recode  \
# 219895               2021                      2022
#
#        Race recode (W, B, AI, API) Site recode ICD-O-3/WHO 2008  Primary Site  \
# 219895                       White            Lung and Bronchus           341
#
#         Primary Site - labeled Derived Summary Grade 2018 (2018+)  ...  \
# 219895  C34.1-Upper lobe, lung                                  2  ...
#
#        COD to site recode               Sequence number  \
# 219895              Alive  34th of 34 or more primaries
#
#        Median household income inflation adj to 2023  \
# 219895                             $85,000 - $89,999
#
#         Number of Cores Positive Recode (2010+)  \
# 219895                                 Blank(s)
#
#        Number of Cores Examined Recode (2010+)  \
# 219895                                Blank(s)
#
#        EOD Primary Tumor Recode (2018+) PRCDA 2020  \
# 219895                              300  Not PRCDA
#
#                                      Survival months flag Survival months  \
# 219895  Complete dates are available and there are mor...            0021
#
#        Vital status recode (study cutoff used)
# 219895                                   Alive
#
# [1 rows x 26 columns]

# %%
df[df["Patient ID"] == 27987549]  # 34개의 원발암이 있는 사람.
# Out:
#         Patient ID Age recode with <1 year olds and 90+     Sex  \
# 219895    27987549                          45-49 years  Female
#
#         Year of diagnosis  Year of follow-up recode  \
# 219895               2021                      2022
#
#        Race recode (W, B, AI, API) Site recode ICD-O-3/WHO 2008  Primary Site  \
# 219895                       White            Lung and Bronchus           341
#
#         Primary Site - labeled Derived Summary Grade 2018 (2018+)  ...  \
# 219895  C34.1-Upper lobe, lung                                  2  ...
#
#        COD to site recode               Sequence number  \
# 219895              Alive  34th of 34 or more primaries
#
#        Median household income inflation adj to 2023  \
# 219895                             $85,000 - $89,999
#
#         Number of Cores Positive Recode (2010+)  \
# 219895                                 Blank(s)
#
#        Number of Cores Examined Recode (2010+)  \
# 219895                                Blank(s)
#
#        EOD Primary Tumor Recode (2018+) PRCDA 2020  \
# 219895                              300  Not PRCDA
#
#                                      Survival months flag Survival months  \
# 219895  Complete dates are available and there are mor...            0021
#
#        Vital status recode (study cutoff used)
# 219895                                   Alive
#
# [1 rows x 26 columns]

# %%
df[df['Sequence number'] == '30th of 30 or more primaries']
# Out:
#         Patient ID Age recode with <1 year olds and 90+     Sex  \
# 303024    36843270                          80-84 years  Female
# 307518    36957438                          70-74 years    Male
#
#         Year of diagnosis  Year of follow-up recode  \
# 303024               2019                      2022
# 307518               2020                      2022
#
#        Race recode (W, B, AI, API) Site recode ICD-O-3/WHO 2008  Primary Site  \
# 303024                       White            Lung and Bronchus           341
# 307518                       White            Lung and Bronchus           341
#
#         Primary Site - labeled Derived Summary Grade 2018 (2018+)  ...  \
# 303024  C34.1-Upper lobe, lung                                  3  ...
# 307518  C34.1-Upper lobe, lung                                  3  ...
#
#        COD to site recode               Sequence number  \
# 303024              Alive  30th of 30 or more primaries
# 307518              Alive  30th of 30 or more primaries
#
#        Median household income inflation adj to 2023  \
# 303024                           $110,000 - $119,999
# 307518                             $80,000 - $84,999
#
#         Number of Cores Positive Recode (2010+)  \
# 303024                                 Blank(s)
# 307518                                 Blank(s)
#
#        Number of Cores Examined Recode (2010+)  \
# 303024                                Blank(s)
# 307518                                Blank(s)
#
#        EOD Primary Tumor Recode (2018+) PRCDA 2020  \
# 303024                              500  Not PRCDA
# 307518                              700      PRCDA
#
#                                      Survival months flag Survival months  \
# 303024  Complete dates are available and there are mor...            0043
# 307518  Complete dates are available and there are mor...            0034
#
#        Vital status recode (study cutoff used)
# 303024                                   Alive
# 307518                                   Alive
#
# [2 rows x 26 columns]

# %%
df[df["Patient ID"] == 36843270]  # 30개의 원발암이 있는 사람.
# Out:
#         Patient ID Age recode with <1 year olds and 90+     Sex  \
# 303024    36843270                          80-84 years  Female
#
#         Year of diagnosis  Year of follow-up recode  \
# 303024               2019                      2022
#
#        Race recode (W, B, AI, API) Site recode ICD-O-3/WHO 2008  Primary Site  \
# 303024                       White            Lung and Bronchus           341
#
#         Primary Site - labeled Derived Summary Grade 2018 (2018+)  ...  \
# 303024  C34.1-Upper lobe, lung                                  3  ...
#
#        COD to site recode               Sequence number  \
# 303024              Alive  30th of 30 or more primaries
#
#        Median household income inflation adj to 2023  \
# 303024                           $110,000 - $119,999
#
#         Number of Cores Positive Recode (2010+)  \
# 303024                                 Blank(s)
#
#        Number of Cores Examined Recode (2010+)  \
# 303024                                Blank(s)
#
#        EOD Primary Tumor Recode (2018+) PRCDA 2020  \
# 303024                              500  Not PRCDA
#
#                                      Survival months flag Survival months  \
# 303024  Complete dates are available and there are mor...            0043
#
#        Vital status recode (study cutoff used)
# 303024                                   Alive
#
# [1 rows x 26 columns]

# %%
df[df["Patient ID"] == 36957438]  # 30개의 원발암이 있는 사람.
# Out:
#         Patient ID Age recode with <1 year olds and 90+   Sex  \
# 307518    36957438                          70-74 years  Male
#
#         Year of diagnosis  Year of follow-up recode  \
# 307518               2020                      2022
#
#        Race recode (W, B, AI, API) Site recode ICD-O-3/WHO 2008  Primary Site  \
# 307518                       White            Lung and Bronchus           341
#
#         Primary Site - labeled Derived Summary Grade 2018 (2018+)  ...  \
# 307518  C34.1-Upper lobe, lung                                  3  ...
#
#        COD to site recode               Sequence number  \
# 307518              Alive  30th of 30 or more primaries
#
#        Median household income inflation adj to 2023  \
# 307518                             $80,000 - $84,999
#
#         Number of Cores Positive Recode (2010+)  \
# 307518                                 Blank(s)
#
#        Number of Cores Examined Recode (2010+)  \
# 307518                                Blank(s)
#
#        EOD Primary Tumor Recode (2018+) PRCDA 2020  \
# 307518                              700      PRCDA
#
#                                      Survival months flag Survival months  \
# 307518  Complete dates are available and there are mor...            0034
#
#        Vital status recode (study cutoff used)
# 307518                                   Alive
#
# [1 rows x 26 columns]

# %%
df[df['Survival months'] == '0000']  # 이 사람들은 생존 여부는 혼재,
# df[df['Survival months'] == 0]  # 숫자형으로 바꿨을 때 조회
# Out:
#         Patient ID Age recode with <1 year olds and 90+     Sex  \
# 443         411137                          85-89 years  Female
# 477         437782                          75-79 years    Male
# 736         595206                            90+ years  Female
# 825         637126                          75-79 years  Female
# 891         664090                          70-74 years  Female
# ...            ...                                  ...     ...
# 528382    63452348                          70-74 years    Male
# 528390    63452512                          70-74 years    Male
# 528391    63452528                          70-74 years    Male
# 528395    63452545                          70-74 years    Male
# 528401    63452565                            90+ years  Female
#
#         Year of diagnosis  Year of follow-up recode  \
# 443                  2022                      2022
# 477                  2022                      2022
# 736                  2022                      2022
# 825                  2022                      2022
# 891                  2022                      2022
# ...                   ...                       ...
# 528382               2021                      2022
# 528390               2022                      2022
# 528391               2022                      2022
# 528395               2022                      2022
# 528401               2022                      2022
#
#        Race recode (W, B, AI, API) Site recode ICD-O-3/WHO 2008  Primary Site  \
# 443                          White       Intrahepatic Bile Duct           221
# 477                          Black            Lung and Bronchus           343
# 736      Asian or Pacific Islander            Lung and Bronchus           349
# 825                          White                        Cecum           180
# 891                          White                        Cecum           180
# ...                            ...                          ...           ...
# 528382                       Black                        Liver           220
# 528390                       White                        Liver           220
# 528391                       White            Lung and Bronchus           349
# 528395                       Black            Lung and Bronchus           349
# 528401                       White         Large Intestine, NOS           189
#
#               Primary Site - labeled Derived Summary Grade 2018 (2018+)  ...  \
# 443     C22.1-Intrahepatic bile duct                                  9  ...
# 477           C34.3-Lower lobe, lung                                  9  ...
# 736                  C34.9-Lung, NOS                                  9  ...
# 825                      C18.0-Cecum                                  3  ...
# 891                      C18.0-Cecum                                  2  ...
# ...                              ...                                ...  ...
# 528382                   C22.0-Liver                                  9  ...
# 528390                   C22.0-Liver                                  9  ...
# 528391               C34.9-Lung, NOS                                  9  ...
# 528395               C34.9-Lung, NOS                                  9  ...
# 528401              C18.9-Colon, NOS                                  9  ...
#
#                     COD to site recode             Sequence number  \
# 443                              Alive  2nd of 2 or more primaries
# 477                           Prostate  3rd of 3 or more primaries
# 736                  Lung and Bronchus  2nd of 2 or more primaries
# 825             Colon excluding Rectum  2nd of 2 or more primaries
# 891                              Alive  3rd of 3 or more primaries
# ...                                ...                         ...
# 528382                           Liver            One primary only
# 528390                           Liver            One primary only
# 528391  Miscellaneous Malignant Cancer            One primary only
# 528395               Lung and Bronchus            One primary only
# 528401          Colon excluding Rectum            One primary only
#
#        Median household income inflation adj to 2023  \
# 443                                        $120,000+
# 477                                        $120,000+
# 736                                        $120,000+
# 825                                        $120,000+
# 891                                        $120,000+
# ...                                              ...
# 528382                             $45,000 - $49,999
# 528390                             $45,000 - $49,999
# 528391                             $70,000 - $74,999
# 528395                             $70,000 - $74,999
# 528401                             $90,000 - $94,999
#
#         Number of Cores Positive Recode (2010+)  \
# 443                                    Blank(s)
# 477                                    Blank(s)
# 736                                    Blank(s)
# 825                                    Blank(s)
# 891                                    Blank(s)
# ...                                         ...
# 528382                                 Blank(s)
# 528390                                 Blank(s)
# 528391                                 Blank(s)
# 528395                                 Blank(s)
# 528401                                 Blank(s)
#
#        Number of Cores Examined Recode (2010+)  \
# 443                                   Blank(s)
# 477                                   Blank(s)
# 736                                   Blank(s)
# 825                                   Blank(s)
# 891                                   Blank(s)
# ...                                        ...
# 528382                                Blank(s)
# 528390                                Blank(s)
# 528391                                Blank(s)
# 528395                                Blank(s)
# 528401                                Blank(s)
#
#        EOD Primary Tumor Recode (2018+) PRCDA 2020  \
# 443                                 300  Not PRCDA
# 477                                 650  Not PRCDA
# 736                                 999  Not PRCDA
# 825                                 999  Not PRCDA
# 891                                 500  Not PRCDA
# ...                                 ...        ...
# 528382                              999  Not PRCDA
# 528390                              999  Not PRCDA
# 528391                              999  Not PRCDA
# 528395                              999  Not PRCDA
# 528401                              999  Not PRCDA
#
#                                      Survival months flag Survival months  \
# 443     Complete dates are available and there are mor...             0.0
# 477     Complete dates are available and there are mor...             0.0
# 736     Complete dates are available and there are mor...             0.0
# 825     Complete dates are available and there are mor...             0.0
# 891     Complete dates are available and there are mor...             0.0
# ...                                                   ...             ...
# 528382  Complete dates are available and there are mor...             0.0
# 528390  Complete dates are available and there are mor...             0.0
# 528391  Complete dates are available and there are mor...             0.0
# 528395  Complete dates are available and there are mor...             0.0
# 528401  Complete dates are available and there are mor...             0.0
#
#        Vital status recode (study cutoff used)
# 443                                      Alive
# 477                                       Dead
# 736                                       Dead
# 825                                       Dead
# 891                                      Alive
# ...                                        ...
# 528382                                    Dead
# 528390                                    Dead
# 528391                                    Dead
# 528395                                    Dead
# 528401                                    Dead
#
# [15392 rows x 26 columns]

# %%
df[df['Survival months'] == 'Unknown']['Vital status recode (study cutoff used)'].value_counts() # 이 사람들은 다 Dead
# df[df['Survival months'].isna()] # 숫자형으로 바꿨을 때 조회
# Out:
#         Patient ID Age recode with <1 year olds and 90+     Sex  \
# 129         111243                            90+ years  Female
# 9333       1228711                            90+ years  Female
# 12460      1346708                          80-84 years    Male
# 14750      1417699                          85-89 years  Female
# 20263      1558003                          85-89 years    Male
# ...            ...                                  ...     ...
# 528339    63450762                          70-74 years    Male
# 528340    63450767                          60-64 years    Male
# 528341    63450773                          55-59 years  Female
# 528342    63450780                          55-59 years  Female
# 528343    63450785                          85-89 years  Female
#
#         Year of diagnosis  Year of follow-up recode  \
# 129                  2022                      2022
# 9333                 2022                      2022
# 12460                2022                      2022
# 14750                2022                      2022
# 20263                2022                      2022
# ...                   ...                       ...
# 528339               2022                      2022
# 528340               2022                      2022
# 528341               2022                      2022
# 528342               2022                      2022
# 528343               2022                      2022
#
#        Race recode (W, B, AI, API) Site recode ICD-O-3/WHO 2008  Primary Site  \
# 129                          Black                        Liver           220
# 9333                         White         Large Intestine, NOS           189
# 12460                        White            Lung and Bronchus           349
# 14750    Asian or Pacific Islander         Large Intestine, NOS           189
# 20263    Asian or Pacific Islander                Sigmoid Colon           187
# ...                            ...                          ...           ...
# 528339                       White            Lung and Bronchus           349
# 528340                       White                        Liver           220
# 528341                       White                      Stomach           169
# 528342                       White         Large Intestine, NOS           189
# 528343                       White            Lung and Bronchus           349
#
#        Primary Site - labeled Derived Summary Grade 2018 (2018+)  ...  \
# 129               C22.0-Liver                                  9  ...
# 9333         C18.9-Colon, NOS                                  9  ...
# 12460         C34.9-Lung, NOS                                  9  ...
# 14750        C18.9-Colon, NOS                                  9  ...
# 20263     C18.7-Sigmoid colon                                  9  ...
# ...                       ...                                ...  ...
# 528339        C34.9-Lung, NOS                                  9  ...
# 528340            C22.0-Liver                                  9  ...
# 528341     C16.9-Stomach, NOS                                  9  ...
# 528342       C18.9-Colon, NOS                                  9  ...
# 528343        C34.9-Lung, NOS                                  9  ...
#
#                        COD to site recode             Sequence number  \
# 129                                 Liver  2nd of 2 or more primaries
# 9333               Colon excluding Rectum  2nd of 2 or more primaries
# 12460                   Lung and Bronchus            One primary only
# 14750              Colon excluding Rectum  2nd of 2 or more primaries
# 20263              Colon excluding Rectum  2nd of 2 or more primaries
# ...                                   ...                         ...
# 528339            Pneumonia and Influenza            One primary only
# 528340                              Liver            One primary only
# 528341                            Stomach            One primary only
# 528342  Suicide and Self-Inflicted Injury            One primary only
# 528343                  Lung and Bronchus            One primary only
#
#        Median household income inflation adj to 2023  \
# 129                                        $120,000+
# 9333                                       $120,000+
# 12460                                      $120,000+
# 14750                                      $120,000+
# 20263                                      $120,000+
# ...                                              ...
# 528339                             $80,000 - $84,999
# 528340                             $55,000 - $59,999
# 528341                             $65,000 - $69,999
# 528342                             $50,000 - $54,999
# 528343                             $90,000 - $94,999
#
#         Number of Cores Positive Recode (2010+)  \
# 129                                    Blank(s)
# 9333                                   Blank(s)
# 12460                                  Blank(s)
# 14750                                  Blank(s)
# 20263                                  Blank(s)
# ...                                         ...
# 528339                                 Blank(s)
# 528340                                 Blank(s)
# 528341                                 Blank(s)
# 528342                                 Blank(s)
# 528343                                 Blank(s)
#
#        Number of Cores Examined Recode (2010+)  \
# 129                                   Blank(s)
# 9333                                  Blank(s)
# 12460                                 Blank(s)
# 14750                                 Blank(s)
# 20263                                 Blank(s)
# ...                                        ...
# 528339                                Blank(s)
# 528340                                Blank(s)
# 528341                                Blank(s)
# 528342                                Blank(s)
# 528343                                Blank(s)
#
#        EOD Primary Tumor Recode (2018+) PRCDA 2020  \
# 129                                 999  Not PRCDA
# 9333                                999  Not PRCDA
# 12460                               999  Not PRCDA
# 14750                               999  Not PRCDA
# 20263                               999  Not PRCDA
# ...                                 ...        ...
# 528339                              999  Not PRCDA
# 528340                              999  Not PRCDA
# 528341                              999  Not PRCDA
# 528342                              999  Not PRCDA
# 528343                              999  Not PRCDA
#
#                                      Survival months flag Survival months  \
# 129     Not calculated because a Death Certificate Onl...             NaN
# 9333    Not calculated because a Death Certificate Onl...             NaN
# 12460   Not calculated because a Death Certificate Onl...             NaN
# 14750   Not calculated because a Death Certificate Onl...             NaN
# 20263   Not calculated because a Death Certificate Onl...             NaN
# ...                                                   ...             ...
# 528339  Not calculated because a Death Certificate Onl...             NaN
# 528340  Not calculated because a Death Certificate Onl...             NaN
# 528341  Not calculated because a Death Certificate Onl...             NaN
# 528342  Not calculated because a Death Certificate Onl...             NaN
# 528343  Not calculated because a Death Certificate Onl...             NaN
#
#        Vital status recode (study cutoff used)
# 129                                       Dead
# 9333                                      Dead
# 12460                                     Dead
# 14750                                     Dead
# 20263                                     Dead
# ...                                        ...
# 528339                                    Dead
# 528340                                    Dead
# 528341                                    Dead
# 528342                                    Dead
# 528343                                    Dead
#
# [2101 rows x 26 columns]

# %% [markdown]
# ### 다수 원발암 vs 단일 원발암 관련 시각화
# 선정 이유
# - 다수 원발암의 환자는 중복된 행을 가지고 있는데 중복된 행이 학습에 불리하게 적용될 수 있으니 어떻게 처리하는 게 좋을지 고민하였다.
# - 그래서 일단 다수 원발암과 단일 원발암 사이에 생존률의 차이가 있는지를 확인하기 위해 다수 원발암과 단일 원발암으로 나눈 후 시각화하였다.
#
# 결론
# - 평균 생존 기간은 다수 원발암이 더 길다.
# - 케플란마이어 그래프를 그려보면 원래 단일암 환자의 생존률이 더 낮다가 약135일을 기준으로 역전된다.
# - 이 데이터를 어떻게 해석할 수 있을까?
#
#
# - 어쨌든 둘의 차이가 있으므로 다수 원발암의 중복 행을 줄이고 다수 원발암임을 알릴 수 있는 컬럼을 추가하는 것도 좋을 것 같다.

# %%
from pathlib import Path
import matplotlib.pyplot as plt
import matplotlib.ticker as mstick
import matplotlib.font_manager as fm 
import matplotlib
import pandas as pd
import seaborn as sns
from lifelines import KaplanMeierFitter # 생존 분석을 위해 추가


# seaborn의 기본 테마를 설정합니다. 'whitegrid' 스타일과 'crest' 색상 팔레트를 사용합니다.
sns.set_theme(style="whitegrid", palette="crest")

# 한글 폰트 사용을 위해 설정한다.
font_path = 'C:\\Windows\\Fonts\\gulim.ttc'
font = fm.FontProperties(fname=font_path).get_name()
matplotlib.rc('font', family=font)

# 마이너스 부호가 깨지는 것을 방지하는 설정입니다.
plt.rc('axes', unicode_minus=False)

# 데이터셋 병합 (사용자 제공 코드와 동일하나, 경로 수정 및 low_memory=False 추가)
DATA_PATH1 = '../data/2022Data_part1.csv'
DATA_PATH2 = '../data/2022Data_part2.csv'
df_part1 = pd.read_csv(DATA_PATH1, low_memory=False)
df_part2 = pd.read_csv(DATA_PATH2, low_memory=False)

# DeepSurv 분석용 샘플 데이터를 불러오고 기본 전처리를 수행합니다.
df = pd.concat([df_part1, df_part2], ignore_index=True).rename(columns=lambda col: col.strip())

# %%
# ----------------------------------------------------------------------
# [추가 코드 시작] - 중복 환자 처리 및 생존 분석
# ----------------------------------------------------------------------

# Feature Engineering: Has_Multiple_Primaries 특성 생성 및 첫 번째 진단만 선택
# 환자 ID별 원발암 개수 계산
primary_counts = df.groupby('Patient ID').size().reset_index(name='Primary_Count')

# 다수 원발암 여부 플래그 생성 (2개 이상이면 1, 아니면 0)
primary_counts['Has_Multiple_Primaries'] = (primary_counts['Primary_Count'] > 1).astype(int)

# 첫 번째 원발암 레코드만 필터링 (다수암 df 중 첫 번째 진단만 남기는 작업 포함)
first_primary_cases = ['One primary only', '1st of 2 or more primaries']
df_single_case = df[df['Sequence number'].isin(first_primary_cases)].copy()

# 필터링된 데이터셋에 다수 원발암 여부 특성 병합
df_final = pd.merge(df_single_case, 
                     primary_counts[['Patient ID', 'Has_Multiple_Primaries']], 
                     on='Patient ID', 
                     how='left')

# 생존 분석을 위한 데이터 전처리
# 'Survival months'를 숫자형으로 변환 및 결측치 제거
df_final['Survival months'] = pd.to_numeric(df_final['Survival months'], errors='coerce')

# Vital Status (생존 상태)를 이벤트(E) 코드로 변환
# 'Dead'을 1 (이벤트 발생), 'Alive'를 0 (중단/Censored)으로 설정
df_final['Event'] = (df_final['Vital status recode (study cutoff used)'] == 'Dead').astype(int)

# 생존 분석에 필요한 컬럼('Survival months', 'Event')에 결측치(NaN)가 있는 행 제거
df_final.dropna(subset=['Survival months', 'Event'], inplace=True)


# 하나의 암 df와 다수 암 df로 분리
# Has_Multiple_Primaries: 0 = 단일 원발암, 1 = 다수 원발암
single_primary_df = df_final[df_final['Has_Multiple_Primaries'] == 0].copy()
multiple_primary_df = df_final[df_final['Has_Multiple_Primaries'] == 1].copy()

print(f"1. 단일 원발암 환자 (One Primary Only) 수: {len(single_primary_df)}명")
print(f"2. 다수 원발암 환자 (Multiple Primaries) 수: {len(multiple_primary_df)}명")
# Out:
# 1. 단일 원발암 환자 (One Primary Only) 수: 396828명
# 2. 다수 원발암 환자 (Multiple Primaries) 수: 19290명

# %%
# print(primary_counts)
df_single_case
# Out:
#         Patient ID Age recode with <1 year olds and 90+     Sex  \
# 1              812                          65-69 years  Female
# 4             1269                          40-44 years  Female
# 8             1913                          55-59 years  Female
# 22            5437                          60-64 years  Female
# 33            8719                          70-74 years  Female
# ...            ...                                  ...     ...
# 528398    63452555                          75-79 years  Female
# 528399    63452558                          70-74 years    Male
# 528400    63452564                          75-79 years    Male
# 528401    63452565                            90+ years  Female
# 528402    63452570                          80-84 years    Male
#
#         Year of diagnosis  Year of follow-up recode  \
# 1                    2022                      2022
# 4                    2007                      2022
# 8                    2020                      2022
# 22                   2018                      2022
# 33                   2002                      2022
# ...                   ...                       ...
# 528398               2022                      2022
# 528399               2022                      2022
# 528400               2022                      2022
# 528401               2022                      2022
# 528402               2020                      2022
#
#        Race recode (W, B, AI, API) Site recode ICD-O-3/WHO 2008  Primary Site  \
# 1                            White                      Stomach           163
# 4                            White                Sigmoid Colon           187
# 8                            White            Lung and Bronchus           341
# 22                           White                Sigmoid Colon           187
# 33                           White             Descending Colon           186
# ...                            ...                          ...           ...
# 528398                       White            Lung and Bronchus           349
# 528399                       Black            Lung and Bronchus           349
# 528400                       White         Large Intestine, NOS           189
# 528401                       White         Large Intestine, NOS           189
# 528402                       White            Lung and Bronchus           349
#
#         Primary Site - labeled Derived Summary Grade 2018 (2018+)  ...  \
# 1         C16.3-Gastric antrum                                  L  ...
# 4          C18.7-Sigmoid colon                           Blank(s)  ...
# 8       C34.1-Upper lobe, lung                                  3  ...
# 22         C18.7-Sigmoid colon                                  2  ...
# 33      C18.6-Descending colon                           Blank(s)  ...
# ...                        ...                                ...  ...
# 528398         C34.9-Lung, NOS                                  9  ...
# 528399         C34.9-Lung, NOS                                  9  ...
# 528400        C18.9-Colon, NOS                                  9  ...
# 528401        C18.9-Colon, NOS                                  9  ...
# 528402         C34.9-Lung, NOS                                  9  ...
#
#                     COD to site recode             Sequence number  \
# 1                                Alive            One primary only
# 4                                Alive            One primary only
# 8                                Alive            One primary only
# 22                               Alive            One primary only
# 33      Miscellaneous Malignant Cancer  1st of 2 or more primaries
# ...                                ...                         ...
# 528398               Lung and Bronchus            One primary only
# 528399               Lung and Bronchus            One primary only
# 528400          Colon excluding Rectum            One primary only
# 528401          Colon excluding Rectum            One primary only
# 528402               Lung and Bronchus            One primary only
#
#        Median household income inflation adj to 2023  \
# 1                                          $120,000+
# 4                                $110,000 - $119,999
# 8                                          $120,000+
# 22                                         $120,000+
# 33                                         $120,000+
# ...                                              ...
# 528398                             $55,000 - $59,999
# 528399                             $50,000 - $54,999
# 528400                             $80,000 - $84,999
# 528401                             $90,000 - $94,999
# 528402                             $45,000 - $49,999
#
#         Number of Cores Positive Recode (2010+)  \
# 1                                      Blank(s)
# 4                                      Blank(s)
# 8                                      Blank(s)
# 22                                     Blank(s)
# 33                                     Blank(s)
# ...                                         ...
# 528398                                 Blank(s)
# 528399                                 Blank(s)
# 528400                                 Blank(s)
# 528401                                 Blank(s)
# 528402                                 Blank(s)
#
#        Number of Cores Examined Recode (2010+)  \
# 1                                     Blank(s)
# 4                                     Blank(s)
# 8                                     Blank(s)
# 22                                    Blank(s)
# 33                                    Blank(s)
# ...                                        ...
# 528398                                Blank(s)
# 528399                                Blank(s)
# 528400                                Blank(s)
# 528401                                Blank(s)
# 528402                                Blank(s)
#
#        EOD Primary Tumor Recode (2018+) PRCDA 2020  \
# 1                                   100  Not PRCDA
# 4                              Blank(s)  Not PRCDA
# 8                                   400  Not PRCDA
# 22                                  100  Not PRCDA
# 33                             Blank(s)  Not PRCDA
# ...                                 ...        ...
# 528398                              999  Not PRCDA
# 528399                              999  Not PRCDA
# 528400                              999  Not PRCDA
# 528401                              999  Not PRCDA
# 528402                              999  Not PRCDA
#
#                                      Survival months flag Survival months  \
# 1       Complete dates are available and there are mor...            0007
# 4       Complete dates are available and there are mor...            0187
# 8       Complete dates are available and there are mor...            0027
# 22      Complete dates are available and there are mor...            0049
# 33      Complete dates are available and there are mor...            0244
# ...                                                   ...             ...
# 528398  Complete dates are available and there are mor...            0002
# 528399  Complete dates are available and there are mor...            0002
# 528400  Complete dates are available and there are mor...            0002
# 528401  Complete dates are available and there are mor...            0000
# 528402  Complete dates are available and there are mor...            0023
#
#        Vital status recode (study cutoff used)
# 1                                        Alive
# 4                                        Alive
# 8                                        Alive
# 22                                       Alive
# 33                                        Dead
# ...                                        ...
# 528398                                    Dead
# 528399                                    Dead
# 528400                                    Dead
# 528401                                    Dead
# 528402                                    Dead
#
# [418036 rows x 26 columns]

# %%
# ----------------------------------------------------------------------
# 평균 생존 기간 막대그래프 (Bar Plot)
# ----------------------------------------------------------------------
avg_survival = df_final.groupby('Has_Multiple_Primaries')['Survival months'].mean().round(2)

plt.figure(figsize=(8, 6))
plt.bar(x=[0, 1], height=avg_survival.values, color=['skyblue', 'lightcoral'])
plt.title('원발암 개수별 평균 생존 기간 비교', fontsize=16)
plt.ylabel('평균 생존 기간 (개월)', fontsize=14)
plt.xlabel('원발암 개수 (0: 단일, 1: 다수)', fontsize=14)
plt.xticks(ticks=[0, 1], labels=['단일 원발암', '다수 원발암'], fontsize=12, rotation=0)

# 막대 위에 값 표시
for i, v in enumerate(avg_survival.values):
    plt.text(i, v + 2, f'{v:.2f}', ha='center', va='bottom', fontsize=12)

plt.ylim(bottom=0)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
# ----------------------------------------------------------------------
# 시간에 따른 생존률 그래프 (Kaplan-Meier Survival Curve)
# ----------------------------------------------------------------------
kmf = KaplanMeierFitter()

plt.figure(figsize=(10, 7))

# 4-1. 단일 원발암 환자 생존 곡선
T_single = single_primary_df['Survival months']
E_single = single_primary_df['Event']
kmf.fit(T_single, event_observed=E_single, label=f'단일 원발암 (N={len(T_single)})')
kmf.plot(ci_show=False, linewidth=2, linestyle='-') 

# 4-2. 다수 원발암 환자 생존 곡선
T_multiple = multiple_primary_df['Survival months']
E_multiple = multiple_primary_df['Event']
kmf.fit(T_multiple, event_observed=E_multiple, label=f'다수 원발암 (N={len(T_multiple)})')
kmf.plot(ci_show=False, linewidth=2, linestyle='--')

plt.title('원발암 개수에 따른 Kaplan-Meier 생존 곡선 (요청 4)', fontsize=16)
plt.xlabel('시간 (Survival Months)', fontsize=14)
plt.ylabel('생존 확률 (Survival Probability)', fontsize=14)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.legend(loc='lower left', fontsize=12)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 데이터의 분포 시각화(성별, 인종, 나이, 진단 연도, 암 부위)

# %%
# 분석할 컬럼의 한글명과 실제 컬럼명 매핑
column_mapping = {
    '성별': 'Sex',
    '인종': 'Race recode (W, B, AI, API)',
    '나이': 'Age recode with <1 year olds and 90+',
    '진단 연도': 'Year of diagnosis',
    '암 부위': 'Site recode ICD-O-3/WHO 2008'
}

# 각 컬럼에 대해 반복하며 그래프 생성
for kor_name, eng_name in column_mapping.items():
    if eng_name in df.columns:
        plt.figure(figsize=(12, 8))
        
        # --- 데이터 계산 ---
        if kor_name == '암 부위':
            # '암 부위'는 종류가 많아 상위 10개만 선택합니다.
            value_counts = df[eng_name].value_counts(normalize=True).nlargest(10)
            title = f'{kor_name} 분포 (상위 10개)'
            order = value_counts.index
        else:
            # 그 외 컬럼은 인덱스 순으로 정렬합니다.
            value_counts = df[eng_name].value_counts(normalize=True).sort_index()
            title = f'{kor_name} 분포'
            # .sort_index()는 숫자나 날짜형식의 문자열에 적합합니다.
            order = sorted(value_counts.index.map(str))

        # 비율을 퍼센트로 변환
        data_percent = value_counts * 100
        
        # --- 시각화 (Seaborn 바 그래프) ---
        # x축 데이터를 hue에도 넘겨주고, 불필요한 범례(legend)는 숨깁니다.
        ax = sns.barplot(x=data_percent.index, y=data_percent.values, hue=data_percent.index, order=order, palette='viridis', legend=False)
        
        # --- 그래프 디자인 ---
        plt.title(title, fontsize=18, pad=20)
        plt.xlabel(kor_name, fontsize=12)
        plt.ylabel('비율 (%)', fontsize=12)
        plt.xticks(rotation=45, ha='right', fontsize=11) # x축 라벨 회전
        
        # 막대 위에 비율(%) 텍스트 표시
        for p in ax.patches:
            height = p.get_height()
            ax.text(p.get_x() + p.get_width() / 2., height, f'{height:.1f}%', ha="center", va='bottom', fontsize=10)

        plt.tight_layout() # 레이아웃 최적화

    else:
        print(f"경고: '{eng_name}' 컬럼을 데이터프레임에서 찾을 수 없습니다.")
