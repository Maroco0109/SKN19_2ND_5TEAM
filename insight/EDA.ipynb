# %% [markdown]
# # EDA 시각화 일괄 실행
#
# modules/DataAnalysis.py의 `show_graph`를 호출하여 insight/data_insight.ipynb의 시각화를 한 번에 재현합니다.

# %%
# 프로젝트 루트를 sys.path에 추가하여 'modules' 임포트 가능하게 설정
from pathlib import Path
import sys
_CWD = Path.cwd()
_ROOT = _CWD.parent if (_CWD.name == 'insight' and (_CWD.parent / 'modules').exists()) else _CWD
if str(_ROOT) not in sys.path:
    sys.path.insert(0, str(_ROOT))
print('Project root:', _ROOT)
# Out:
# Project root: /home/maroco/SKN19_2ND_5TEAM

# %%
# 필요한 모듈 임포트 및 시각화 실행
from modules.DataAnalysis import show_graph
import pandas as pd
from pathlib import Path

# encoded_dataset_COD.csv를 로드하여 DataFrame으로 전달
candidates = [
    Path('data/encoded_dataset_COD.csv'),
    Path('../data/encoded_dataset_COD.csv'),
    Path('data/EDA/encoded_dataset_COD.csv'),
    Path('../data/EDA/encoded_dataset_COD.csv'),
]
df = None
for p in candidates:
    if p.exists():
        df = pd.read_csv(p)
        print(f'Loaded: {p}')
        break
if df is None:
    raise FileNotFoundError('encoded_dataset_COD.csv not found in expected paths')

show_graph(df)
# Out:
# Loaded: ../data/encoded_dataset_COD.csv
# /home/maroco/miniconda3/envs/Team5/lib/python3.9/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# [DataAnalysis] Saved figure: img/plot_corr_with_target.png
# [DataAnalysis] Saved axes: img/plot_corr_with_target_ax01.png
# [DataAnalysis] Saved axes: img/plot_corr_with_target_ax02.png
# [DataAnalysis] Saved figure: img/plot_corr_with_target.png
# [DataAnalysis] Saved axes: img/plot_corr_with_target_ax01.png
# [DataAnalysis] Saved axes: img/plot_corr_with_target_ax02.png
# [DataAnalysis] Saved figure: img/plot_survival_months.png
# [DataAnalysis] Saved axes: img/plot_survival_months_ax01.png
# [DataAnalysis] Saved figure: img/plot_survival_months.png
# [DataAnalysis] Saved axes: img/plot_survival_months_ax01.png
# [DataAnalysis] Saved figure: img/plot_basic_distributions.png
# ...
