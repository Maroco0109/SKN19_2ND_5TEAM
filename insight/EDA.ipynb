# %% [markdown]
# # EDA 시각화 일괄 실행
#
# modules/DataAnalysis.py의 `show_graph`를 호출하여 insight/data_insight.ipynb의 시각화를 한 번에 재현합니다.

# %%
# 프로젝트 루트를 sys.path에 추가하여 'modules' 임포트 가능하게 설정
from pathlib import Path
import sys
_CWD = Path.cwd()
_ROOT = _CWD.parent if (_CWD.name == 'insight' and (_CWD.parent / 'modules').exists()) else _CWD
if str(_ROOT) not in sys.path:
    sys.path.insert(0, str(_ROOT))
print('Project root:', _ROOT)
# Out:
# Project root: /home/maroco/SKN19_2ND_5TEAM

# %%
# 필요한 모듈 임포트 및 시각화 실행
from modules.DataAnalysis import show_graph
# 기본: data/encoded_dataset.csv, data/EDA/encoded_dataset_COD.csv 사용
show_graph(None)
# Out:
# /home/maroco/SKN19_2ND_5TEAM/modules/DataAnalysis.py:655: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(tick_labels)
# /home/maroco/SKN19_2ND_5TEAM/modules/DataAnalysis.py:794: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) NanumGothic.
#   plt.tight_layout(); plt.show()
# /home/maroco/SKN19_2ND_5TEAM/modules/DataAnalysis.py:794: UserWarning: Glyph 128200 (\N{CHART WITH UPWARDS TREND}) missing from font(s) NanumGothic.
#   plt.tight_layout(); plt.show()
# /home/maroco/SKN19_2ND_5TEAM/modules/DataAnalysis.py:794: UserWarning: Glyph 127919 (\N{DIRECT HIT}) missing from font(s) NanumGothic.
#   plt.tight_layout(); plt.show()
# /home/maroco/SKN19_2ND_5TEAM/modules/DataAnalysis.py:794: UserWarning: Glyph 9889 (\N{HIGH VOLTAGE SIGN}) missing from font(s) NanumGothic.
#   plt.tight_layout(); plt.show()
# ...
